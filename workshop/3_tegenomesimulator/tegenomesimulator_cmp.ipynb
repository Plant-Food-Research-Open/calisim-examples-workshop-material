# %%
! python /mnt/c/Users/james/projects/TEgenomeSimulator/TEgenomeSimulator/TEgenomeSimulator.py -M 0 -p reference_simulation1 -r data/fake_repeat.fa -c data/random_genome_chr_index_small.csv -o data
! python /mnt/c/Users/james/projects/TEgenomeSimulator/TEgenomeSimulator/TEgenomeSimulator.py -M 0 -p reference_simulation2 -r data/fake_repeat.fa -c data/random_genome_chr_index_small.csv -o data
# Out:
# [2025-08-15 10:01:44.025882] TEgenomeSimulator started.
# [2025-08-15 10:01:44.025962] Arguments: {'mode': 0, 'to_mask': False, 'prefix': 'reference_simulation1', 'repeat': 'data/fake_repeat.fa', 'repeat2': None, 'maxcp': 10, 'mincp': 1, 'maxidn': 95, 'minidn': 80, 'maxsd': 20, 'minsd': 1, 'chridx': 'data/random_genome_chr_index_small.csv', 'genome': None, 'alpha': 0.5, 'beta': 0.7, 'intact': 0.001, 'seed': 1, 'threads': 1, 'outdir': 'data'}
# Output Directory: /mnt/c/Users/james/projects/calisim-examples/workshop/tegenomesimulator/data/TEgenomeSimulator_reference_simulation1_result
# Mode: 0
# Running Random Synthesized mode.
# Prefix: reference_simulation1
# Repeat: data/fake_repeat.fa
# Chromosome Index: data/random_genome_chr_index_small.csv
# Genome File: None
# Alpha: 0.5
# Beta: 0.7
# Max Copies: 10
# Min Copies: 1
# Upper bound of mean identity: 95
# Lower bound of mean identity: 80
# Upper bound of sd of mean identity: 20
# Lower bound of sd of mean ideneity: 1
# ...

# %%
! tegenomesimulator -M 0 -p reference_simulation1 -r data/fake_repeat.fa -c data/random_genome_chr_index_small.csv -o data
! tegenomesimulator -M 0 -p reference_simulation2 -r data/fake_repeat.fa -c data/random_genome_chr_index_small.csv -o data
# Out:
# [2025-08-15 10:50:42.376574] TEgenomeSimulator started.
# [2025-08-15 10:50:42.376671] Arguments: {'mode': 0, 'to_mask': False, 'prefix': 'reference_simulation1', 'repeat': 'data/fake_repeat.fa', 'repeat2': None, 'maxcp': 10, 'mincp': 1, 'maxidn': 95, 'minidn': 80, 'maxsd': 20, 'minsd': 1, 'chridx': 'data/random_genome_chr_index_small.csv', 'genome': None, 'alpha': 0.5, 'beta': 0.7, 'intact': 0.001, 'seed': 1, 'threads': 1, 'outdir': 'data'}
# Output Directory: /mnt/c/Users/james/projects/calisim-examples/workshop/tegenomesimulator/data/TEgenomeSimulator_reference_simulation1_result
# Mode: 0
# Running Random Synthesized mode.
# Prefix: reference_simulation1
# Repeat: data/fake_repeat.fa
# Chromosome Index: data/random_genome_chr_index_small.csv
# Genome File: None
# Alpha: 0.5
# Beta: 0.7
# Max Copies: 10
# Min Copies: 1
# Upper bound of mean identity: 95
# Lower bound of mean identity: 80
# Upper bound of sd of mean identity: 20
# Lower bound of sd of mean ideneity: 1
# ...

# %%
! cmp data/TEgenomeSimulator_reference_simulation1_result/reference_simulation1_genome_sequence_out_final.fasta data/TEgenomeSimulator_reference_simulation2_result/reference_simulation2_genome_sequence_out_final.fasta
