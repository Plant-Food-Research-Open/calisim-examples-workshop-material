# %% [markdown]
# # Imports

# %%
from subprocess import Popen
from pathlib import Path

# %% [markdown]
# # Utility functions
#
# Define utility functions.

# %%
def get_uuid():
    return str(uuid.uuid4())

def load_genome_sequence(filepath):
    with open(filepath, 'r') as f:
        lines = f.readlines()
    sequence = ''.join([line.strip() for line in lines if not line.startswith('>')])
    return sequence.upper()

def build_kmers(sequence, ksize):
    kmers = []
    n_kmers = len(sequence) - ksize + 1

    for i in range(n_kmers):
        kmer = sequence[i : i + ksize]
        kmers.append(kmer)

    return kmers

def jaccard_similarity(a, b):
    a = set(a)
    b = set(b)

    intersection = len(a.intersection(b))
    union = len(a.union(b))

    return intersection / union

# %% [markdown]
# # Reference simulation
#
# Execute the reference simulation.

# %%
# Reference values

M = 0
c=str(Path("data", "random_genome_chr_index.csv"))
r=str(Path("data", "combined_curated_TE_lib_ATOSZM_selected.fasta"))
o="data"
maxidn=95
minidn=80
maxsd=20
minsd=1
a=0.7
b=0.5
i=0.001
m=5
n=1
k = 100   
batch_size = 64

p="reference_simulation"
cmd = f"tegenomesimulator -M {M} -p {p} -c {c} -r {r} -o {o} -a {a} -b {b} -i {i} -m {m} -n {n} --maxidn {maxidn} --minidn {minidn} --maxsd {maxsd} --minsd {minsd}"
Popen(cmd, shell=True).wait()
# Out:
# Mode: 0
# Running Random Synthesized mode.
# Prefix: reference_simulation
# Repeat: data/combined_curated_TE_lib_ATOSZM_selected.fasta
# Chromosome Index: data/random_genome_chr_index.csv
# Genome File: None
# Alpha: 0.7
# Beta: 0.5
# Max Copies: 5
# Min Copies: 1
# Upper bound of mean identity: 95
# Lower bound of mean identity: 80
# Upper bound of sd of mean identity: 20
# Lower bound of sd of mean ideneity: 1
# Max chance of intact insertion: 0.001
# Seed: 1
# Output Directory: data
#
# TE library table generated successfully. Output logged to data/TEgenomeSimulator_reference_simulation_result/TEgenomeSimulator.log
# mode=0, running prep_yml_config.py for Random Genome Mode.
#
# Config file generated successfully. Output logged to data/TEgenomeSimulator_reference_simulation_result/TEgenomeSimulator.log
#
# Genome with non-overlap random TE insertions was generated successfully. Output logged to data/TEgenomeSimulator_reference_simulation_result/TEgenomeSimulator.log
#
# Genome with non-overlap random and nested TE insertions was generated successfully. Output logged to data/TEgenomeSimulator_reference_simulation_result/TEgenomeSimulator.log
# 0

# %% [markdown]
# Load the genome sequence data to string.

# %%
reference_genome_sequence_path = f"{o}/TEgenomeSimulator_{p}_result/{p}_genome_sequence_out_final.fasta"
reference_genome_sequence = load_genome_sequence(reference_genome_sequence_path)
build_kmers(reference_genome_sequence, 21)
# Out:
# ['TGAAAAATTTTGACAGTTAAG',
#  'GAAAAATTTTGACAGTTAAGC',
#  'AAAAATTTTGACAGTTAAGCA',
#  'AAAATTTTGACAGTTAAGCAG',
#  'AAATTTTGACAGTTAAGCAGC',
#  'AATTTTGACAGTTAAGCAGCC',
#  'ATTTTGACAGTTAAGCAGCCA',
#  'TTTTGACAGTTAAGCAGCCAA',
#  'TTTGACAGTTAAGCAGCCAAA',
#  'TTGACAGTTAAGCAGCCAAAC',
#  'TGACAGTTAAGCAGCCAAACA',
#  'GACAGTTAAGCAGCCAAACAT',
#  'ACAGTTAAGCAGCCAAACATC',
#  'CAGTTAAGCAGCCAAACATCT',
#  'AGTTAAGCAGCCAAACATCTG',
#  'GTTAAGCAGCCAAACATCTGA',
#  'TTAAGCAGCCAAACATCTGAG',
#  'TAAGCAGCCAAACATCTGAGC',
#  'AAGCAGCCAAACATCTGAGCA',
#  'AGCAGCCAAACATCTGAGCAG',
#  'GCAGCCAAACATCTGAGCAGC',
#  'CAGCCAAACATCTGAGCAGCG',
#  'AGCCAAACATCTGAGCAGCGA',
#  'GCCAAACATCTGAGCAGCGAG',
#  'CCAAACATCTGAGCAGCGAGA',
#  'CAAACATCTGAGCAGCGAGAT',
#  'AAACATCTGAGCAGCGAGATC',
#  'AACATCTGAGCAGCGAGATCA',
#  'ACATCTGAGCAGCGAGATCAA',
#  'CATCTGAGCAGCGAGATCAAA',
#  'ATCTGAGCAGCGAGATCAAAA',
#  'TCTGAGCAGCGAGATCAAAAG',
#  'CTGAGCAGCGAGATCAAAAGA',
#  'TGAGCAGCGAGATCAAAAGAA',
#  'GAGCAGCGAGATCAAAAGAAT',
#  'AGCAGCGAGATCAAAAGAATA',
#  'GCAGCGAGATCAAAAGAATAT',
#  'CAGCGAGATCAAAAGAATATA',
#  'AGCGAGATCAAAAGAATATAT',
#  'GCGAGATCAAAAGAATATATG',
#  'CGAGATCAAAAGAATATATGA',
#  'GAGATCAAAAGAATATATGAT',
#  'AGATCAAAAGAATATATGATG',
#  'GATCAAAAGAATATATGATGT',
#  'ATCAAAAGAATATATGATGTA',
#  'TCAAAAGAATATATGATGTAT',
#  'CAAAAGAATATATGATGTATG',
#  'AAAAGAATATATGATGTATGT',
#  'AAAGAATATATGATGTATGTC',
#  'AAGAATATATGATGTATGTCT',
#  'AGAATATATGATGTATGTCTC',
#  'GAATATATGATGTATGTCTCA',
#  'AATATATGATGTATGTCTCAA',
#  'ATATATGATGTATGTCTCAAG',
#  'TATATGATGTATGTCTCAAGT',
#  'ATATGATGTATGTCTCAAGTA',
#  'TATGATGTATGTCTCAAGTAC',
#  'ATGATGTATGTCTCAAGTACT',
#  'TGATGTATGTCTCAAGTACTG',
#  'GATGTATGTCTCAAGTACTGG',
#  'ATGTATGTCTCAAGTACTGGC',
#  'TGTATGTCTCAAGTACTGGCT',
#  'GTATGTCTCAAGTACTGGCTG',
#  'TATGTCTCAAGTACTGGCTGT',
#  'ATGTCTCAAGTACTGGCTGTA',
#  'TGTCTCAAGTACTGGCTGTAC',
#  'GTCTCAAGTACTGGCTGTACT',
#  'TCTCAAGTACTGGCTGTACTC',
#  'CTCAAGTACTGGCTGTACTCG',
#  'TCAAGTACTGGCTGTACTCGT',
#  'CAAGTACTGGCTGTACTCGTA',
#  'AAGTACTGGCTGTACTCGTAC',
#  'AGTACTGGCTGTACTCGTACT',
#  'GTACTGGCTGTACTCGTACTT',
#  'TACTGGCTGTACTCGTACTTT',
#  'ACTGGCTGTACTCGTACTTTA',
#  'CTGGCTGTACTCGTACTTTAC',
#  'TGGCTGTACTCGTACTTTACT',
#  'GGCTGTACTCGTACTTTACTA',
#  'GCTGTACTCGTACTTTACTAT',
#  'CTGTACTCGTACTTTACTATT',
#  'TGTACTCGTACTTTACTATTT',
#  'GTACTCGTACTTTACTATTTC',
#  'TACTCGTACTTTACTATTTCT',
#  'ACTCGTACTTTACTATTTCTC',
#  'CTCGTACTTTACTATTTCTCT',
#  'TCGTACTTTACTATTTCTCTA',
#  'CGTACTTTACTATTTCTCTAC',
#  'GTACTTTACTATTTCTCTACG',
#  'TACTTTACTATTTCTCTACGC',
#  'ACTTTACTATTTCTCTACGCA',
#  'CTTTACTATTTCTCTACGCAA',
#  'TTTACTATTTCTCTACGCAAC',
#  'TTACTATTTCTCTACGCAACG',
#  'TACTATTTCTCTACGCAACGA',
#  'ACTATTTCTCTACGCAACGAG',
#  'CTATTTCTCTACGCAACGAGG',
#  'TATTTCTCTACGCAACGAGGC',
#  'ATTTCTCTACGCAACGAGGCG',
#  'TTTCTCTACGCAACGAGGCGA',
#  'TTCTCTACGCAACGAGGCGAA',
#  'TCTCTACGCAACGAGGCGAAA',
#  'CTCTACGCAACGAGGCGAAAA',
#  'TCTACGCAACGAGGCGAAAAA',
#  'CTACGCAACGAGGCGAAAAAC',
#  'TACGCAACGAGGCGAAAAACT',
#  'ACGCAACGAGGCGAAAAACTT',
#  'CGCAACGAGGCGAAAAACTTC',
#  'GCAACGAGGCGAAAAACTTCA',
#  'CAACGAGGCGAAAAACTTCAA',
#  'AACGAGGCGAAAAACTTCAAT',
#  'ACGAGGCGAAAAACTTCAATC',
#  'CGAGGCGAAAAACTTCAATCT',
#  'GAGGCGAAAAACTTCAATCTA',
#  'AGGCGAAAAACTTCAATCTAG',
#  'GGCGAAAAACTTCAATCTAGA',
#  'GCGAAAAACTTCAATCTAGAG',
#  'CGAAAAACTTCAATCTAGAGT',
#  'GAAAAACTTCAATCTAGAGTC',
#  'AAAAACTTCAATCTAGAGTCG',
#  'AAAACTTCAATCTAGAGTCGT',
#  'AAACTTCAATCTAGAGTCGTA',
#  'AACTTCAATCTAGAGTCGTAA',
#  'ACTTCAATCTAGAGTCGTAAA',
#  'CTTCAATCTAGAGTCGTAAAA',
#  'TTCAATCTAGAGTCGTAAAAA',
#  'TCAATCTAGAGTCGTAAAAAA',
#  'CAATCTAGAGTCGTAAAAAAG',
#  'AATCTAGAGTCGTAAAAAAGT',
#  'ATCTAGAGTCGTAAAAAAGTA',
#  'TCTAGAGTCGTAAAAAAGTAA',
#  'CTAGAGTCGTAAAAAAGTAAC',
#  'TAGAGTCGTAAAAAAGTAACT',
#  'AGAGTCGTAAAAAAGTAACTA',
#  'GAGTCGTAAAAAAGTAACTAA',
#  'AGTCGTAAAAAAGTAACTAAG',
#  'GTCGTAAAAAAGTAACTAAGA',
#  'TCGTAAAAAAGTAACTAAGAT',
#  'CGTAAAAAAGTAACTAAGATC',
#  'GTAAAAAAGTAACTAAGATCC',
#  'TAAAAAAGTAACTAAGATCCA',
#  'AAAAAAGTAACTAAGATCCAT',
#  'AAAAAGTAACTAAGATCCATT',
#  'AAAAGTAACTAAGATCCATTC',
#  'AAAGTAACTAAGATCCATTCA',
#  'AAGTAACTAAGATCCATTCAA',
#  'AGTAACTAAGATCCATTCAAA',
#  'GTAACTAAGATCCATTCAAAT',
#  'TAACTAAGATCCATTCAAATT',
#  'AACTAAGATCCATTCAAATTT',
#  'ACTAAGATCCATTCAAATTTA',
#  'CTAAGATCCATTCAAATTTAC',
#  'TAAGATCCATTCAAATTTACT',
#  'AAGATCCATTCAAATTTACTT',
#  'AGATCCATTCAAATTTACTTT',
#  'GATCCATTCAAATTTACTTTG',
#  'ATCCATTCAAATTTACTTTGG',
#  'TCCATTCAAATTTACTTTGGA',
#  'CCATTCAAATTTACTTTGGAA',
#  'CATTCAAATTTACTTTGGAAT',
#  'ATTCAAATTTACTTTGGAATT',
#  'TTCAAATTTACTTTGGAATTA',
#  'TCAAATTTACTTTGGAATTAG',
#  'CAAATTTACTTTGGAATTAGA',
#  'AAATTTACTTTGGAATTAGAA',
#  'AATTTACTTTGGAATTAGAAG',
#  'ATTTACTTTGGAATTAGAAGA',
#  'TTTACTTTGGAATTAGAAGAT',
#  'TTACTTTGGAATTAGAAGATT',
#  'TACTTTGGAATTAGAAGATTC',
#  'ACTTTGGAATTAGAAGATTCA',
#  'CTTTGGAATTAGAAGATTCAA',
#  'TTTGGAATTAGAAGATTCAAG',
#  'TTGGAATTAGAAGATTCAAGG',
#  'TGGAATTAGAAGATTCAAGGC',
#  'GGAATTAGAAGATTCAAGGCC',
#  'GAATTAGAAGATTCAAGGCCA',
#  'AATTAGAAGATTCAAGGCCAA',
#  'ATTAGAAGATTCAAGGCCAAT',
#  'TTAGAAGATTCAAGGCCAATC',
#  'TAGAAGATTCAAGGCCAATCC',
#  'AGAAGATTCAAGGCCAATCCT',
#  'GAAGATTCAAGGCCAATCCTC',
#  'AAGATTCAAGGCCAATCCTCT',
#  'AGATTCAAGGCCAATCCTCTT',
#  'GATTCAAGGCCAATCCTCTTT',
#  'ATTCAAGGCCAATCCTCTTTT',
#  'TTCAAGGCCAATCCTCTTTTT',
#  'TCAAGGCCAATCCTCTTTTTC',
#  'CAAGGCCAATCCTCTTTTTCC',
#  'AAGGCCAATCCTCTTTTTCCT',
#  'AGGCCAATCCTCTTTTTCCTC',
#  'GGCCAATCCTCTTTTTCCTCA',
#  'GCCAATCCTCTTTTTCCTCAA',
#  'CCAATCCTCTTTTTCCTCAAA',
#  'CAATCCTCTTTTTCCTCAAAT',
#  'AATCCTCTTTTTCCTCAAATA',
#  'ATCCTCTTTTTCCTCAAATAC',
#  'TCCTCTTTTTCCTCAAATACC',
#  'CCTCTTTTTCCTCAAATACCA',
#  'CTCTTTTTCCTCAAATACCAA',
#  'TCTTTTTCCTCAAATACCAAT',
#  'CTTTTTCCTCAAATACCAATA',
#  'TTTTTCCTCAAATACCAATAG',
#  'TTTTCCTCAAATACCAATAGT',
#  'TTTCCTCAAATACCAATAGTC',
#  'TTCCTCAAATACCAATAGTCT',
#  'TCCTCAAATACCAATAGTCTC',
#  'CCTCAAATACCAATAGTCTCC',
#  'CTCAAATACCAATAGTCTCCC',
#  'TCAAATACCAATAGTCTCCCT',
#  'CAAATACCAATAGTCTCCCTT',
#  'AAATACCAATAGTCTCCCTTG',
#  'AATACCAATAGTCTCCCTTGA',
#  'ATACCAATAGTCTCCCTTGAT',
#  'TACCAATAGTCTCCCTTGATT',
#  'ACCAATAGTCTCCCTTGATTA',
#  'CCAATAGTCTCCCTTGATTAT',
#  'CAATAGTCTCCCTTGATTATT',
#  'AATAGTCTCCCTTGATTATTG',
#  'ATAGTCTCCCTTGATTATTGA',
#  'TAGTCTCCCTTGATTATTGAC',
#  'AGTCTCCCTTGATTATTGACT',
#  'GTCTCCCTTGATTATTGACTA',
#  'TCTCCCTTGATTATTGACTAG',
#  'CTCCCTTGATTATTGACTAGT',
#  'TCCCTTGATTATTGACTAGTA',
#  'CCCTTGATTATTGACTAGTAT',
#  'CCTTGATTATTGACTAGTATG',
#  'CTTGATTATTGACTAGTATGC',
#  'TTGATTATTGACTAGTATGCA',
#  'TGATTATTGACTAGTATGCAC',
#  'GATTATTGACTAGTATGCACT',
#  'ATTATTGACTAGTATGCACTC',
#  'TTATTGACTAGTATGCACTCT',
#  'TATTGACTAGTATGCACTCTC',
#  'ATTGACTAGTATGCACTCTCT',
#  'TTGACTAGTATGCACTCTCTT',
#  'TGACTAGTATGCACTCTCTTA',
#  'GACTAGTATGCACTCTCTTAT',
#  'ACTAGTATGCACTCTCTTATG',
#  'CTAGTATGCACTCTCTTATGC',
#  'TAGTATGCACTCTCTTATGCG',
#  'AGTATGCACTCTCTTATGCGG',
#  'GTATGCACTCTCTTATGCGGC',
#  'TATGCACTCTCTTATGCGGCA',
#  'ATGCACTCTCTTATGCGGCAG',
#  'TGCACTCTCTTATGCGGCAGT',
#  'GCACTCTCTTATGCGGCAGTT',
#  'CACTCTCTTATGCGGCAGTTT',
#  'ACTCTCTTATGCGGCAGTTTT',
#  'CTCTCTTATGCGGCAGTTTTA',
#  'TCTCTTATGCGGCAGTTTTAT',
#  'CTCTTATGCGGCAGTTTTATT',
#  'TCTTATGCGGCAGTTTTATTC',
#  'CTTATGCGGCAGTTTTATTCG',
#  'TTATGCGGCAGTTTTATTCGA',
#  'TATGCGGCAGTTTTATTCGAT',
#  'ATGCGGCAGTTTTATTCGATT',
#  'TGCGGCAGTTTTATTCGATTG',
#  'GCGGCAGTTTTATTCGATTGC',
#  'CGGCAGTTTTATTCGATTGCC',
#  'GGCAGTTTTATTCGATTGCCG',
#  'GCAGTTTTATTCGATTGCCGA',
#  'CAGTTTTATTCGATTGCCGAA',
#  'AGTTTTATTCGATTGCCGAAC',
#  'GTTTTATTCGATTGCCGAACT',
#  'TTTTATTCGATTGCCGAACTG',
#  'TTTATTCGATTGCCGAACTGT',
#  'TTATTCGATTGCCGAACTGTG',
#  'TATTCGATTGCCGAACTGTGT',
#  'ATTCGATTGCCGAACTGTGTG',
#  'TTCGATTGCCGAACTGTGTGT',
#  'TCGATTGCCGAACTGTGTGTT',
#  'CGATTGCCGAACTGTGTGTTT',
#  'GATTGCCGAACTGTGTGTTTA',
#  'ATTGCCGAACTGTGTGTTTAT',
#  'TTGCCGAACTGTGTGTTTATA',
#  'TGCCGAACTGTGTGTTTATAC',
#  'GCCGAACTGTGTGTTTATACA',
#  'CCGAACTGTGTGTTTATACAG',
#  'CGAACTGTGTGTTTATACAGC',
#  'GAACTGTGTGTTTATACAGCG',
#  'AACTGTGTGTTTATACAGCGT',
#  'ACTGTGTGTTTATACAGCGTA',
#  'CTGTGTGTTTATACAGCGTAT',
#  'TGTGTGTTTATACAGCGTATT',
#  'GTGTGTTTATACAGCGTATTA',
#  'TGTGTTTATACAGCGTATTAT',
#  'GTGTTTATACAGCGTATTATT',
#  'TGTTTATACAGCGTATTATTG',
#  'GTTTATACAGCGTATTATTGG',
#  'TTTATACAGCGTATTATTGGA',
#  'TTATACAGCGTATTATTGGAA',
#  'TATACAGCGTATTATTGGAAG',
#  'ATACAGCGTATTATTGGAAGT',
#  'TACAGCGTATTATTGGAAGTC',
#  'ACAGCGTATTATTGGAAGTCT',
#  'CAGCGTATTATTGGAAGTCTG',
#  'AGCGTATTATTGGAAGTCTGG',
#  'GCGTATTATTGGAAGTCTGGG',
#  'CGTATTATTGGAAGTCTGGGC',
#  'GTATTATTGGAAGTCTGGGCC',
#  'TATTATTGGAAGTCTGGGCCT',
#  'ATTATTGGAAGTCTGGGCCTG',
#  'TTATTGGAAGTCTGGGCCTGT',
#  'TATTGGAAGTCTGGGCCTGTT',
#  'ATTGGAAGTCTGGGCCTGTTC',
#  'TTGGAAGTCTGGGCCTGTTCG',
#  'TGGAAGTCTGGGCCTGTTCGG',
#  'GGAAGTCTGGGCCTGTTCGGC',
#  'GAAGTCTGGGCCTGTTCGGCT',
#  'AAGTCTGGGCCTGTTCGGCTG',
#  'AGTCTGGGCCTGTTCGGCTGG',
#  'GTCTGGGCCTGTTCGGCTGGC',
#  'TCTGGGCCTGTTCGGCTGGCT',
#  'CTGGGCCTGTTCGGCTGGCTG',
#  'TGGGCCTGTTCGGCTGGCTGG',
#  'GGGCCTGTTCGGCTGGCTGGT',
#  'GGCCTGTTCGGCTGGCTGGTA',
#  'GCCTGTTCGGCTGGCTGGTAC',
#  'CCTGTTCGGCTGGCTGGTACA',
#  'CTGTTCGGCTGGCTGGTACAG',
#  'TGTTCGGCTGGCTGGTACAGC',
#  'GTTCGGCTGGCTGGTACAGCC',
#  'TTCGGCTGGCTGGTACAGCCA',
#  'TCGGCTGGCTGGTACAGCCAC',
#  'CGGCTGGCTGGTACAGCCACT',
#  'GGCTGGCTGGTACAGCCACTG',
#  'GCTGGCTGGTACAGCCACTGT',
#  'CTGGCTGGTACAGCCACTGTA',
#  'TGGCTGGTACAGCCACTGTAC',
#  'GGCTGGTACAGCCACTGTACG',
#  'GCTGGTACAGCCACTGTACGC',
#  'CTGGTACAGCCACTGTACGCA',
#  'TGGTACAGCCACTGTACGCAG',
#  'GGTACAGCCACTGTACGCAGC',
#  'GTACAGCCACTGTACGCAGCC',
#  'TACAGCCACTGTACGCAGCCG',
#  'ACAGCCACTGTACGCAGCCGT',
#  'CAGCCACTGTACGCAGCCGTG',
#  'AGCCACTGTACGCAGCCGTGG',
#  'GCCACTGTACGCAGCCGTGGC',
#  'CCACTGTACGCAGCCGTGGCT',
#  'CACTGTACGCAGCCGTGGCTG',
#  'ACTGTACGCAGCCGTGGCTGC',
#  'CTGTACGCAGCCGTGGCTGCT',
#  'TGTACGCAGCCGTGGCTGCTG',
#  'GTACGCAGCCGTGGCTGCTGC',
#  'TACGCAGCCGTGGCTGCTGCA',
#  'ACGCAGCCGTGGCTGCTGCAG',
#  'CGCAGCCGTGGCTGCTGCAGC',
#  'GCAGCCGTGGCTGCTGCAGCT',
#  'CAGCCGTGGCTGCTGCAGCTG',
#  'AGCCGTGGCTGCTGCAGCTGC',
#  'GCCGTGGCTGCTGCAGCTGCA',
#  'CCGTGGCTGCTGCAGCTGCAG',
#  'CGTGGCTGCTGCAGCTGCAGA',
#  'GTGGCTGCTGCAGCTGCAGAC',
#  'TGGCTGCTGCAGCTGCAGACT',
#  'GGCTGCTGCAGCTGCAGACTC',
#  'GCTGCTGCAGCTGCAGACTCA',
#  'CTGCTGCAGCTGCAGACTCAA',
#  'TGCTGCAGCTGCAGACTCAAC',
#  'GCTGCAGCTGCAGACTCAACT',
#  'CTGCAGCTGCAGACTCAACTT',
#  'TGCAGCTGCAGACTCAACTTA',
#  'GCAGCTGCAGACTCAACTTAC',
#  'CAGCTGCAGACTCAACTTACT',
#  'AGCTGCAGACTCAACTTACTG',
#  'GCTGCAGACTCAACTTACTGT',
#  'CTGCAGACTCAACTTACTGTT',
#  'TGCAGACTCAACTTACTGTTT',
#  'GCAGACTCAACTTACTGTTTG',
#  'CAGACTCAACTTACTGTTTGT',
#  'AGACTCAACTTACTGTTTGTG',
#  'GACTCAACTTACTGTTTGTGT',
#  'ACTCAACTTACTGTTTGTGTT',
#  'CTCAACTTACTGTTTGTGTTG',
#  'TCAACTTACTGTTTGTGTTGG',
#  'CAACTTACTGTTTGTGTTGGC',
#  'AACTTACTGTTTGTGTTGGCT',
#  'ACTTACTGTTTGTGTTGGCTG',
#  'CTTACTGTTTGTGTTGGCTGC',
#  'TTACTGTTTGTGTTGGCTGCA',
#  'TACTGTTTGTGTTGGCTGCAA',
#  'ACTGTTTGTGTTGGCTGCAAA',
#  'CTGTTTGTGTTGGCTGCAAAA',
#  'TGTTTGTGTTGGCTGCAAAAC',
#  'GTTTGTGTTGGCTGCAAAACA',
#  'TTTGTGTTGGCTGCAAAACAG',
#  'TTGTGTTGGCTGCAAAACAGT',
#  'TGTGTTGGCTGCAAAACAGTG',
#  'GTGTTGGCTGCAAAACAGTGA',
#  'TGTTGGCTGCAAAACAGTGAA',
#  'GTTGGCTGCAAAACAGTGAAG',
#  'TTGGCTGCAAAACAGTGAAGT',
#  'TGGCTGCAAAACAGTGAAGTG',
#  'GGCTGCAAAACAGTGAAGTGA',
#  'GCTGCAAAACAGTGAAGTGAA',
#  'CTGCAAAACAGTGAAGTGAAG',
#  'TGCAAAACAGTGAAGTGAAGT',
#  'GCAAAACAGTGAAGTGAAGTA',
#  'CAAAACAGTGAAGTGAAGTAC',
#  'AAAACAGTGAAGTGAAGTACA',
#  'AAACAGTGAAGTGAAGTACAG',
#  'AACAGTGAAGTGAAGTACAGC',
#  'ACAGTGAAGTGAAGTACAGCC',
#  'CAGTGAAGTGAAGTACAGCCG',
#  'AGTGAAGTGAAGTACAGCCGA',
#  'GTGAAGTGAAGTACAGCCGAA',
#  'TGAAGTGAAGTACAGCCGAAC',
#  'GAAGTGAAGTACAGCCGAACA',
#  'AAGTGAAGTACAGCCGAACAG',
#  'AGTGAAGTACAGCCGAACAGG',
#  'GTGAAGTACAGCCGAACAGGC',
#  'TGAAGTACAGCCGAACAGGCC',
#  'GAAGTACAGCCGAACAGGCCC',
#  'AAGTACAGCCGAACAGGCCCT',
#  'AGTACAGCCGAACAGGCCCTG',
#  'GTACAGCCGAACAGGCCCTGG',
#  'TACAGCCGAACAGGCCCTGGA',
#  'ACAGCCGAACAGGCCCTGGAA',
#  'CAGCCGAACAGGCCCTGGAAG',
#  'AGCCGAACAGGCCCTGGAAGT',
#  'GCCGAACAGGCCCTGGAAGTC',
#  'CCGAACAGGCCCTGGAAGTCT',
#  'CGAACAGGCCCTGGAAGTCTA',
#  'GAACAGGCCCTGGAAGTCTAC',
#  'AACAGGCCCTGGAAGTCTACC',
#  'ACAGGCCCTGGAAGTCTACCA',
#  'CAGGCCCTGGAAGTCTACCAA',
#  'AGGCCCTGGAAGTCTACCAAA',
#  'GGCCCTGGAAGTCTACCAAAT',
#  'GCCCTGGAAGTCTACCAAATG',
#  'CCCTGGAAGTCTACCAAATGA',
#  'CCTGGAAGTCTACCAAATGAA',
#  'CTGGAAGTCTACCAAATGAAC',
#  'TGGAAGTCTACCAAATGAACT',
#  'GGAAGTCTACCAAATGAACTT',
#  'GAAGTCTACCAAATGAACTTA',
#  'AAGTCTACCAAATGAACTTAA',
#  'AGTCTACCAAATGAACTTAAT',
#  'GTCTACCAAATGAACTTAATT',
#  'TCTACCAAATGAACTTAATTA',
#  'CTACCAAATGAACTTAATTAT',
#  'TACCAAATGAACTTAATTATT',
#  'ACCAAATGAACTTAATTATTG',
#  'CCAAATGAACTTAATTATTGA',
#  'CAAATGAACTTAATTATTGAG',
#  'AAATGAACTTAATTATTGAGA',
#  'AATGAACTTAATTATTGAGAT',
#  'ATGAACTTAATTATTGAGATG',
#  'TGAACTTAATTATTGAGATGA',
#  'GAACTTAATTATTGAGATGAA',
#  'AACTTAATTATTGAGATGAAC',
#  'ACTTAATTATTGAGATGAACC',
#  'CTTAATTATTGAGATGAACCT',
#  'TTAATTATTGAGATGAACCTC',
#  'TAATTATTGAGATGAACCTCC',
#  'AATTATTGAGATGAACCTCCC',
#  'ATTATTGAGATGAACCTCCCC',
#  'TTATTGAGATGAACCTCCCCA',
#  'TATTGAGATGAACCTCCCCAG',
#  'ATTGAGATGAACCTCCCCAGG',
#  'TTGAGATGAACCTCCCCAGGT',
#  'TGAGATGAACCTCCCCAGGTG',
#  'GAGATGAACCTCCCCAGGTGA',
#  'AGATGAACCTCCCCAGGTGAG',
#  'GATGAACCTCCCCAGGTGAGG',
#  'ATGAACCTCCCCAGGTGAGGA',
#  'TGAACCTCCCCAGGTGAGGAA',
#  'GAACCTCCCCAGGTGAGGAAT',
#  'AACCTCCCCAGGTGAGGAATT',
#  'ACCTCCCCAGGTGAGGAATTG',
#  'CCTCCCCAGGTGAGGAATTGT',
#  'CTCCCCAGGTGAGGAATTGTG',
#  'TCCCCAGGTGAGGAATTGTGC',
#  'CCCCAGGTGAGGAATTGTGCA',
#  'CCCAGGTGAGGAATTGTGCAA',
#  'CCAGGTGAGGAATTGTGCAAC',
#  'CAGGTGAGGAATTGTGCAACT',
#  'AGGTGAGGAATTGTGCAACTC',
#  'GGTGAGGAATTGTGCAACTCT',
#  'GTGAGGAATTGTGCAACTCTC',
#  'TGAGGAATTGTGCAACTCTCT',
#  'GAGGAATTGTGCAACTCTCTT',
#  'AGGAATTGTGCAACTCTCTTA',
#  'GGAATTGTGCAACTCTCTTAT',
#  'GAATTGTGCAACTCTCTTATA',
#  'AATTGTGCAACTCTCTTATAA',
#  'ATTGTGCAACTCTCTTATAAG',
#  'TTGTGCAACTCTCTTATAAGA',
#  'TGTGCAACTCTCTTATAAGAT',
#  'GTGCAACTCTCTTATAAGATC',
#  'TGCAACTCTCTTATAAGATCG',
#  'GCAACTCTCTTATAAGATCGG',
#  'CAACTCTCTTATAAGATCGGA',
#  'AACTCTCTTATAAGATCGGAT',
#  'ACTCTCTTATAAGATCGGATT',
#  'CTCTCTTATAAGATCGGATTC',
#  'TCTCTTATAAGATCGGATTCA',
#  'CTCTTATAAGATCGGATTCAA',
#  'TCTTATAAGATCGGATTCAAA',
#  'CTTATAAGATCGGATTCAAAG',
#  'TTATAAGATCGGATTCAAAGT',
#  'TATAAGATCGGATTCAAAGTA',
#  'ATAAGATCGGATTCAAAGTAT',
#  'TAAGATCGGATTCAAAGTATA',
#  'AAGATCGGATTCAAAGTATAG',
#  'AGATCGGATTCAAAGTATAGA',
#  'GATCGGATTCAAAGTATAGAA',
#  'ATCGGATTCAAAGTATAGAAT',
#  'TCGGATTCAAAGTATAGAATC',
#  'CGGATTCAAAGTATAGAATCT',
#  'GGATTCAAAGTATAGAATCTG',
#  'GATTCAAAGTATAGAATCTGT',
#  'ATTCAAAGTATAGAATCTGTT',
#  'TTCAAAGTATAGAATCTGTTC',
#  'TCAAAGTATAGAATCTGTTCG',
#  'CAAAGTATAGAATCTGTTCGA',
#  'AAAGTATAGAATCTGTTCGAG',
#  'AAGTATAGAATCTGTTCGAGT',
#  'AGTATAGAATCTGTTCGAGTC',
#  'GTATAGAATCTGTTCGAGTCA',
#  'TATAGAATCTGTTCGAGTCAA',
#  'ATAGAATCTGTTCGAGTCAAA',
#  'TAGAATCTGTTCGAGTCAAAT',
#  'AGAATCTGTTCGAGTCAAATA',
#  'GAATCTGTTCGAGTCAAATAT',
#  'AATCTGTTCGAGTCAAATATG',
#  'ATCTGTTCGAGTCAAATATGG',
#  'TCTGTTCGAGTCAAATATGGG',
#  'CTGTTCGAGTCAAATATGGGT',
#  'TGTTCGAGTCAAATATGGGTC',
#  'GTTCGAGTCAAATATGGGTCT',
#  'TTCGAGTCAAATATGGGTCTG',
#  'TCGAGTCAAATATGGGTCTGT',
#  'CGAGTCAAATATGGGTCTGTA',
#  'GAGTCAAATATGGGTCTGTAA',
#  'AGTCAAATATGGGTCTGTAAA',
#  'GTCAAATATGGGTCTGTAAAA',
#  'TCAAATATGGGTCTGTAAAAT',
#  'CAAATATGGGTCTGTAAAATA',
#  'AAATATGGGTCTGTAAAATAA',
#  'AATATGGGTCTGTAAAATAAG',
#  'ATATGGGTCTGTAAAATAAGT',
#  'TATGGGTCTGTAAAATAAGTG',
#  'ATGGGTCTGTAAAATAAGTGT',
#  'TGGGTCTGTAAAATAAGTGTT',
#  'GGGTCTGTAAAATAAGTGTTT',
#  'GGTCTGTAAAATAAGTGTTTT',
#  'GTCTGTAAAATAAGTGTTTTG',
#  'TCTGTAAAATAAGTGTTTTGT',
#  'CTGTAAAATAAGTGTTTTGTC',
#  'TGTAAAATAAGTGTTTTGTCA',
#  'GTAAAATAAGTGTTTTGTCAG',
#  'TAAAATAAGTGTTTTGTCAGA',
#  'AAAATAAGTGTTTTGTCAGAT',
#  'AAATAAGTGTTTTGTCAGATA',
#  'AATAAGTGTTTTGTCAGATAT',
#  'ATAAGTGTTTTGTCAGATATG',
#  'TAAGTGTTTTGTCAGATATGG',
#  'AAGTGTTTTGTCAGATATGGA',
#  'AGTGTTTTGTCAGATATGGAA',
#  'GTGTTTTGTCAGATATGGAAG',
#  'TGTTTTGTCAGATATGGAAGT',
#  'GTTTTGTCAGATATGGAAGTC',
#  'TTTTGTCAGATATGGAAGTCT',
#  'TTTGTCAGATATGGAAGTCTC',
#  'TTGTCAGATATGGAAGTCTCA',
#  'TGTCAGATATGGAAGTCTCAT',
#  'GTCAGATATGGAAGTCTCATC',
#  'TCAGATATGGAAGTCTCATCG',
#  'CAGATATGGAAGTCTCATCGG',
#  'AGATATGGAAGTCTCATCGGC',
#  'GATATGGAAGTCTCATCGGCG',
#  'ATATGGAAGTCTCATCGGCGG',
#  'TATGGAAGTCTCATCGGCGGA',
#  'ATGGAAGTCTCATCGGCGGAA',
#  'TGGAAGTCTCATCGGCGGAAG',
#  'GGAAGTCTCATCGGCGGAAGC',
#  'GAAGTCTCATCGGCGGAAGCA',
#  'AAGTCTCATCGGCGGAAGCAT',
#  'AGTCTCATCGGCGGAAGCATG',
#  'GTCTCATCGGCGGAAGCATGG',
#  'TCTCATCGGCGGAAGCATGGC',
#  'CTCATCGGCGGAAGCATGGCA',
#  'TCATCGGCGGAAGCATGGCAC',
#  'CATCGGCGGAAGCATGGCACG',
#  'ATCGGCGGAAGCATGGCACGC',
#  'TCGGCGGAAGCATGGCACGCC',
#  'CGGCGGAAGCATGGCACGCCA',
#  'GGCGGAAGCATGGCACGCCAC',
#  'GCGGAAGCATGGCACGCCACT',
#  'CGGAAGCATGGCACGCCACTG',
#  'GGAAGCATGGCACGCCACTGC',
#  'GAAGCATGGCACGCCACTGCA',
#  'AAGCATGGCACGCCACTGCAC',
#  'AGCATGGCACGCCACTGCACG',
#  'GCATGGCACGCCACTGCACGG',
#  'CATGGCACGCCACTGCACGGG',
#  'ATGGCACGCCACTGCACGGGC',
#  'TGGCACGCCACTGCACGGGCA',
#  'GGCACGCCACTGCACGGGCAG',
#  'GCACGCCACTGCACGGGCAGG',
#  'CACGCCACTGCACGGGCAGGC',
#  'ACGCCACTGCACGGGCAGGCG',
#  'CGCCACTGCACGGGCAGGCGC',
#  'GCCACTGCACGGGCAGGCGCC',
#  'CCACTGCACGGGCAGGCGCCC',
#  'CACTGCACGGGCAGGCGCCCG',
#  'ACTGCACGGGCAGGCGCCCGG',
#  'CTGCACGGGCAGGCGCCCGGG',
#  'TGCACGGGCAGGCGCCCGGGC',
#  'GCACGGGCAGGCGCCCGGGCT',
#  'CACGGGCAGGCGCCCGGGCTT',
#  'ACGGGCAGGCGCCCGGGCTTT',
#  'CGGGCAGGCGCCCGGGCTTTG',
#  'GGGCAGGCGCCCGGGCTTTGC',
#  'GGCAGGCGCCCGGGCTTTGCA',
#  'GCAGGCGCCCGGGCTTTGCAG',
#  'CAGGCGCCCGGGCTTTGCAGC',
#  'AGGCGCCCGGGCTTTGCAGCA',
#  'GGCGCCCGGGCTTTGCAGCAT',
#  'GCGCCCGGGCTTTGCAGCATA',
#  'CGCCCGGGCTTTGCAGCATAT',
#  'GCCCGGGCTTTGCAGCATATA',
#  'CCCGGGCTTTGCAGCATATAT',
#  'CCGGGCTTTGCAGCATATATT',
#  'CGGGCTTTGCAGCATATATTC',
#  'GGGCTTTGCAGCATATATTCA',
#  'GGCTTTGCAGCATATATTCAT',
#  'GCTTTGCAGCATATATTCATG',
#  'CTTTGCAGCATATATTCATGC',
#  'TTTGCAGCATATATTCATGCA',
#  'TTGCAGCATATATTCATGCAT',
#  'TGCAGCATATATTCATGCATT',
#  'GCAGCATATATTCATGCATTA',
#  'CAGCATATATTCATGCATTAG',
#  'AGCATATATTCATGCATTAGA',
#  'GCATATATTCATGCATTAGAA',
#  'CATATATTCATGCATTAGAAC',
#  'ATATATTCATGCATTAGAACT',
#  'TATATTCATGCATTAGAACTA',
#  'ATATTCATGCATTAGAACTAA',
#  'TATTCATGCATTAGAACTAAA',
#  'ATTCATGCATTAGAACTAAAA',
#  'TTCATGCATTAGAACTAAAAT',
#  'TCATGCATTAGAACTAAAATT',
#  'CATGCATTAGAACTAAAATTG',
#  'ATGCATTAGAACTAAAATTGG',
#  'TGCATTAGAACTAAAATTGGC',
#  'GCATTAGAACTAAAATTGGCG',
#  'CATTAGAACTAAAATTGGCGC',
#  'ATTAGAACTAAAATTGGCGCT',
#  'TTAGAACTAAAATTGGCGCTT',
#  'TAGAACTAAAATTGGCGCTTA',
#  'AGAACTAAAATTGGCGCTTAG',
#  'GAACTAAAATTGGCGCTTAGG',
#  'AACTAAAATTGGCGCTTAGGC',
#  'ACTAAAATTGGCGCTTAGGCA',
#  'CTAAAATTGGCGCTTAGGCAG',
#  'TAAAATTGGCGCTTAGGCAGT',
#  'AAAATTGGCGCTTAGGCAGTA',
#  'AAATTGGCGCTTAGGCAGTAG',
#  'AATTGGCGCTTAGGCAGTAGC',
#  'ATTGGCGCTTAGGCAGTAGCC',
#  'TTGGCGCTTAGGCAGTAGCCT',
#  'TGGCGCTTAGGCAGTAGCCTA',
#  'GGCGCTTAGGCAGTAGCCTAG',
#  'GCGCTTAGGCAGTAGCCTAGC',
#  'CGCTTAGGCAGTAGCCTAGCT',
#  'GCTTAGGCAGTAGCCTAGCTC',
#  'CTTAGGCAGTAGCCTAGCTCC',
#  'TTAGGCAGTAGCCTAGCTCCA',
#  'TAGGCAGTAGCCTAGCTCCAC',
#  'AGGCAGTAGCCTAGCTCCACA',
#  'GGCAGTAGCCTAGCTCCACAT',
#  'GCAGTAGCCTAGCTCCACATG',
#  'CAGTAGCCTAGCTCCACATGC',
#  'AGTAGCCTAGCTCCACATGCA',
#  'GTAGCCTAGCTCCACATGCAC',
#  'TAGCCTAGCTCCACATGCACC',
#  'AGCCTAGCTCCACATGCACCA',
#  'GCCTAGCTCCACATGCACCAT',
#  'CCTAGCTCCACATGCACCATT',
#  'CTAGCTCCACATGCACCATTA',
#  'TAGCTCCACATGCACCATTAG',
#  'AGCTCCACATGCACCATTAGA',
#  'GCTCCACATGCACCATTAGAT',
#  'CTCCACATGCACCATTAGATT',
#  'TCCACATGCACCATTAGATTA',
#  'CCACATGCACCATTAGATTAG',
#  'CACATGCACCATTAGATTAGC',
#  'ACATGCACCATTAGATTAGCA',
#  'CATGCACCATTAGATTAGCAA',
#  'ATGCACCATTAGATTAGCAAT',
#  'TGCACCATTAGATTAGCAATA',
#  'GCACCATTAGATTAGCAATAA',
#  'CACCATTAGATTAGCAATAAT',
#  'ACCATTAGATTAGCAATAATT',
#  'CCATTAGATTAGCAATAATTT',
#  'CATTAGATTAGCAATAATTTT',
#  'ATTAGATTAGCAATAATTTTC',
#  'TTAGATTAGCAATAATTTTCA',
#  'TAGATTAGCAATAATTTTCAT',
#  'AGATTAGCAATAATTTTCATA',
#  'GATTAGCAATAATTTTCATAC',
#  'ATTAGCAATAATTTTCATACT',
#  'TTAGCAATAATTTTCATACTT',
#  'TAGCAATAATTTTCATACTTA',
#  'AGCAATAATTTTCATACTTAG',
#  'GCAATAATTTTCATACTTAGT',
#  'CAATAATTTTCATACTTAGTC',
#  'AATAATTTTCATACTTAGTCT',
#  'ATAATTTTCATACTTAGTCTA',
#  'TAATTTTCATACTTAGTCTAG',
#  'AATTTTCATACTTAGTCTAGT',
#  'ATTTTCATACTTAGTCTAGTA',
#  'TTTTCATACTTAGTCTAGTAG',
#  'TTTCATACTTAGTCTAGTAGC',
#  'TTCATACTTAGTCTAGTAGCT',
#  'TCATACTTAGTCTAGTAGCTA',
#  'CATACTTAGTCTAGTAGCTAA',
#  'ATACTTAGTCTAGTAGCTAAA',
#  'TACTTAGTCTAGTAGCTAAAA',
#  'ACTTAGTCTAGTAGCTAAAAA',
#  'CTTAGTCTAGTAGCTAAAAAC',
#  'TTAGTCTAGTAGCTAAAAACC',
#  'TAGTCTAGTAGCTAAAAACCC',
#  'AGTCTAGTAGCTAAAAACCCA',
#  'GTCTAGTAGCTAAAAACCCAC',
#  'TCTAGTAGCTAAAAACCCACT',
#  'CTAGTAGCTAAAAACCCACTT',
#  'TAGTAGCTAAAAACCCACTTC',
#  'AGTAGCTAAAAACCCACTTCT',
#  'GTAGCTAAAAACCCACTTCTA',
#  'TAGCTAAAAACCCACTTCTAC',
#  'AGCTAAAAACCCACTTCTACT',
#  'GCTAAAAACCCACTTCTACTT',
#  'CTAAAAACCCACTTCTACTTC',
#  'TAAAAACCCACTTCTACTTCT',
#  'AAAAACCCACTTCTACTTCTA',
#  'AAAACCCACTTCTACTTCTAT',
#  'AAACCCACTTCTACTTCTATT',
#  'AACCCACTTCTACTTCTATTC',
#  'ACCCACTTCTACTTCTATTCA',
#  'CCCACTTCTACTTCTATTCAT',
#  'CCACTTCTACTTCTATTCATG',
#  'CACTTCTACTTCTATTCATGA',
#  'ACTTCTACTTCTATTCATGAT',
#  'CTTCTACTTCTATTCATGATA',
#  'TTCTACTTCTATTCATGATAA',
#  'TCTACTTCTATTCATGATAAG',
#  'CTACTTCTATTCATGATAAGA',
#  'TACTTCTATTCATGATAAGAT',
#  'ACTTCTATTCATGATAAGATG',
#  'CTTCTATTCATGATAAGATGC',
#  'TTCTATTCATGATAAGATGCT',
#  'TCTATTCATGATAAGATGCTA',
#  'CTATTCATGATAAGATGCTAC',
#  'TATTCATGATAAGATGCTACA',
#  'ATTCATGATAAGATGCTACAT',
#  'TTCATGATAAGATGCTACATG',
#  'TCATGATAAGATGCTACATGT',
#  'CATGATAAGATGCTACATGTA',
#  'ATGATAAGATGCTACATGTAT',
#  'TGATAAGATGCTACATGTATT',
#  'GATAAGATGCTACATGTATTT',
#  'ATAAGATGCTACATGTATTTG',
#  'TAAGATGCTACATGTATTTGT',
#  'AAGATGCTACATGTATTTGTG',
#  'AGATGCTACATGTATTTGTGT',
#  'GATGCTACATGTATTTGTGTT',
#  'ATGCTACATGTATTTGTGTTT',
#  'TGCTACATGTATTTGTGTTTA',
#  'GCTACATGTATTTGTGTTTAC',
#  'CTACATGTATTTGTGTTTACA',
#  'TACATGTATTTGTGTTTACAT',
#  'ACATGTATTTGTGTTTACATG',
#  'CATGTATTTGTGTTTACATGT',
#  'ATGTATTTGTGTTTACATGTT',
#  'TGTATTTGTGTTTACATGTTA',
#  'GTATTTGTGTTTACATGTTAA',
#  'TATTTGTGTTTACATGTTAAT',
#  'ATTTGTGTTTACATGTTAATT',
#  'TTTGTGTTTACATGTTAATTT',
#  'TTGTGTTTACATGTTAATTTG',
#  'TGTGTTTACATGTTAATTTGT',
#  'GTGTTTACATGTTAATTTGTT',
#  'TGTTTACATGTTAATTTGTTT',
#  'GTTTACATGTTAATTTGTTTT',
#  'TTTACATGTTAATTTGTTTTT',
#  'TTACATGTTAATTTGTTTTTT',
#  'TACATGTTAATTTGTTTTTTA',
#  'ACATGTTAATTTGTTTTTTAT',
#  'CATGTTAATTTGTTTTTTATC',
#  'ATGTTAATTTGTTTTTTATCG',
#  'TGTTAATTTGTTTTTTATCGC',
#  'GTTAATTTGTTTTTTATCGCA',
#  'TTAATTTGTTTTTTATCGCAA',
#  'TAATTTGTTTTTTATCGCAAG',
#  'AATTTGTTTTTTATCGCAAGA',
#  'ATTTGTTTTTTATCGCAAGAT',
#  'TTTGTTTTTTATCGCAAGATT',
#  'TTGTTTTTTATCGCAAGATTT',
#  'TGTTTTTTATCGCAAGATTTT',
#  'GTTTTTTATCGCAAGATTTTC',
#  'TTTTTTATCGCAAGATTTTCT',
#  'TTTTTATCGCAAGATTTTCTC',
#  'TTTTATCGCAAGATTTTCTCA',
#  'TTTATCGCAAGATTTTCTCAG',
#  'TTATCGCAAGATTTTCTCAGG',
#  'TATCGCAAGATTTTCTCAGGC',
#  'ATCGCAAGATTTTCTCAGGCT',
#  'TCGCAAGATTTTCTCAGGCTA',
#  'CGCAAGATTTTCTCAGGCTAC',
#  'GCAAGATTTTCTCAGGCTACG',
#  'CAAGATTTTCTCAGGCTACGA',
#  'AAGATTTTCTCAGGCTACGAC',
#  'AGATTTTCTCAGGCTACGACA',
#  'GATTTTCTCAGGCTACGACAA',
#  'ATTTTCTCAGGCTACGACAAA',
#  'TTTTCTCAGGCTACGACAAAT',
#  'TTTCTCAGGCTACGACAAATG',
#  'TTCTCAGGCTACGACAAATGT',
#  'TCTCAGGCTACGACAAATGTT',
#  'CTCAGGCTACGACAAATGTTT',
#  'TCAGGCTACGACAAATGTTTA',
#  'CAGGCTACGACAAATGTTTAG',
#  'AGGCTACGACAAATGTTTAGA',
#  'GGCTACGACAAATGTTTAGAT',
#  'GCTACGACAAATGTTTAGATT',
#  'CTACGACAAATGTTTAGATTG',
#  'TACGACAAATGTTTAGATTGC',
#  'ACGACAAATGTTTAGATTGCA',
#  'CGACAAATGTTTAGATTGCAT',
#  'GACAAATGTTTAGATTGCATT',
#  'ACAAATGTTTAGATTGCATTG',
#  'CAAATGTTTAGATTGCATTGG',
#  'AAATGTTTAGATTGCATTGGA',
#  'AATGTTTAGATTGCATTGGAA',
#  'ATGTTTAGATTGCATTGGAAG',
#  'TGTTTAGATTGCATTGGAAGT',
#  'GTTTAGATTGCATTGGAAGTC',
#  'TTTAGATTGCATTGGAAGTCT',
#  'TTAGATTGCATTGGAAGTCTT',
#  'TAGATTGCATTGGAAGTCTTA',
#  'AGATTGCATTGGAAGTCTTAC',
#  'GATTGCATTGGAAGTCTTACC',
#  'ATTGCATTGGAAGTCTTACCG',
#  'TTGCATTGGAAGTCTTACCGC',
#  'TGCATTGGAAGTCTTACCGCA',
#  'GCATTGGAAGTCTTACCGCAA',
#  'CATTGGAAGTCTTACCGCAAA',
#  'ATTGGAAGTCTTACCGCAAAT',
#  'TTGGAAGTCTTACCGCAAATC',
#  'TGGAAGTCTTACCGCAAATCC',
#  'GGAAGTCTTACCGCAAATCCG',
#  'GAAGTCTTACCGCAAATCCGG',
#  'AAGTCTTACCGCAAATCCGGC',
#  'AGTCTTACCGCAAATCCGGCT',
#  'GTCTTACCGCAAATCCGGCTA',
#  'TCTTACCGCAAATCCGGCTAA',
#  'CTTACCGCAAATCCGGCTAAA',
#  'TTACCGCAAATCCGGCTAAAG',
#  'TACCGCAAATCCGGCTAAAGA',
#  'ACCGCAAATCCGGCTAAAGAA',
#  'CCGCAAATCCGGCTAAAGAAG',
#  'CGCAAATCCGGCTAAAGAAGA',
#  'GCAAATCCGGCTAAAGAAGAC',
#  'CAAATCCGGCTAAAGAAGACA',
#  'AAATCCGGCTAAAGAAGACAT',
#  'AATCCGGCTAAAGAAGACATA',
#  'ATCCGGCTAAAGAAGACATAC',
#  'TCCGGCTAAAGAAGACATACT',
#  'CCGGCTAAAGAAGACATACTT',
#  'CGGCTAAAGAAGACATACTTT',
#  'GGCTAAAGAAGACATACTTTC',
#  'GCTAAAGAAGACATACTTTCA',
#  'CTAAAGAAGACATACTTTCAG',
#  'TAAAGAAGACATACTTTCAGC',
#  'AAAGAAGACATACTTTCAGCA',
#  'AAGAAGACATACTTTCAGCAT',
#  'AGAAGACATACTTTCAGCATT',
#  'GAAGACATACTTTCAGCATTC',
#  'AAGACATACTTTCAGCATTCT',
#  'AGACATACTTTCAGCATTCTG',
#  'GACATACTTTCAGCATTCTGT',
#  'ACATACTTTCAGCATTCTGTT',
#  'CATACTTTCAGCATTCTGTTA',
#  'ATACTTTCAGCATTCTGTTAA',
#  'TACTTTCAGCATTCTGTTAAT',
#  'ACTTTCAGCATTCTGTTAATA',
#  'CTTTCAGCATTCTGTTAATAT',
#  'TTTCAGCATTCTGTTAATATC',
#  'TTCAGCATTCTGTTAATATCT',
#  'TCAGCATTCTGTTAATATCTA',
#  'CAGCATTCTGTTAATATCTAT',
#  'AGCATTCTGTTAATATCTATC',
#  'GCATTCTGTTAATATCTATCC',
#  'CATTCTGTTAATATCTATCCC',
#  'ATTCTGTTAATATCTATCCCC',
#  'TTCTGTTAATATCTATCCCCA',
#  'TCTGTTAATATCTATCCCCAA',
#  'CTGTTAATATCTATCCCCAAA',
#  'TGTTAATATCTATCCCCAAAA',
#  'GTTAATATCTATCCCCAAAAA',
#  'TTAATATCTATCCCCAAAAAT',
#  'TAATATCTATCCCCAAAAATT',
#  'AATATCTATCCCCAAAAATTG',
#  'ATATCTATCCCCAAAAATTGA',
#  'TATCTATCCCCAAAAATTGAG',
#  'ATCTATCCCCAAAAATTGAGA',
#  'TCTATCCCCAAAAATTGAGAT',
#  'CTATCCCCAAAAATTGAGATT',
#  'TATCCCCAAAAATTGAGATTA',
#  'ATCCCCAAAAATTGAGATTAA',
#  'TCCCCAAAAATTGAGATTAAG',
#  'CCCCAAAAATTGAGATTAAGT',
#  'CCCAAAAATTGAGATTAAGTT',
#  'CCAAAAATTGAGATTAAGTTA',
#  'CAAAAATTGAGATTAAGTTAT',
#  'AAAAATTGAGATTAAGTTATC',
#  'AAAATTGAGATTAAGTTATCG',
#  'AAATTGAGATTAAGTTATCGT',
#  'AATTGAGATTAAGTTATCGTC',
#  'ATTGAGATTAAGTTATCGTCC',
#  'TTGAGATTAAGTTATCGTCCT',
#  'TGAGATTAAGTTATCGTCCTA',
#  'GAGATTAAGTTATCGTCCTAA',
#  'AGATTAAGTTATCGTCCTAAA',
#  'GATTAAGTTATCGTCCTAAAT',
#  'ATTAAGTTATCGTCCTAAATT',
#  'TTAAGTTATCGTCCTAAATTC',
#  'TAAGTTATCGTCCTAAATTCA',
#  'AAGTTATCGTCCTAAATTCAC',
#  'AGTTATCGTCCTAAATTCACG',
#  'GTTATCGTCCTAAATTCACGG',
#  'TTATCGTCCTAAATTCACGGT',
#  'TATCGTCCTAAATTCACGGTG',
#  'ATCGTCCTAAATTCACGGTGT',
#  'TCGTCCTAAATTCACGGTGTA',
#  'CGTCCTAAATTCACGGTGTAT',
#  'GTCCTAAATTCACGGTGTATT',
#  'TCCTAAATTCACGGTGTATTG',
#  'CCTAAATTCACGGTGTATTGT',
#  'CTAAATTCACGGTGTATTGTT',
#  'TAAATTCACGGTGTATTGTTA',
#  'AAATTCACGGTGTATTGTTAA',
#  'AATTCACGGTGTATTGTTAAG',
#  'ATTCACGGTGTATTGTTAAGA',
#  'TTCACGGTGTATTGTTAAGAC',
#  'TCACGGTGTATTGTTAAGACA',
#  'CACGGTGTATTGTTAAGACAT',
#  'ACGGTGTATTGTTAAGACATT',
#  'CGGTGTATTGTTAAGACATTG',
#  'GGTGTATTGTTAAGACATTGT',
#  'GTGTATTGTTAAGACATTGTA',
#  'TGTATTGTTAAGACATTGTAA',
#  'GTATTGTTAAGACATTGTAAT',
#  'TATTGTTAAGACATTGTAATG',
#  'ATTGTTAAGACATTGTAATGG',
#  'TTGTTAAGACATTGTAATGGA',
#  'TGTTAAGACATTGTAATGGAA',
#  'GTTAAGACATTGTAATGGAAT',
#  'TTAAGACATTGTAATGGAATG',
#  'TAAGACATTGTAATGGAATGA',
#  'AAGACATTGTAATGGAATGAG',
#  'AGACATTGTAATGGAATGAGG',
#  'GACATTGTAATGGAATGAGGT',
#  'ACATTGTAATGGAATGAGGTC',
#  'CATTGTAATGGAATGAGGTCT',
#  'ATTGTAATGGAATGAGGTCTA',
#  'TTGTAATGGAATGAGGTCTAT',
#  'TGTAATGGAATGAGGTCTATC',
#  'GTAATGGAATGAGGTCTATCC',
#  'TAATGGAATGAGGTCTATCCT',
#  'AATGGAATGAGGTCTATCCTG',
#  'ATGGAATGAGGTCTATCCTGT',
#  'TGGAATGAGGTCTATCCTGTA',
#  'GGAATGAGGTCTATCCTGTAT',
#  'GAATGAGGTCTATCCTGTATG',
#  'AATGAGGTCTATCCTGTATGT',
#  'ATGAGGTCTATCCTGTATGTC',
#  'TGAGGTCTATCCTGTATGTCA',
#  'GAGGTCTATCCTGTATGTCAG',
#  'AGGTCTATCCTGTATGTCAGA',
#  'GGTCTATCCTGTATGTCAGAG',
#  'GTCTATCCTGTATGTCAGAGT',
#  'TCTATCCTGTATGTCAGAGTG',
#  'CTATCCTGTATGTCAGAGTGT',
#  'TATCCTGTATGTCAGAGTGTA',
#  'ATCCTGTATGTCAGAGTGTAG',
#  'TCCTGTATGTCAGAGTGTAGA',
#  'CCTGTATGTCAGAGTGTAGAG',
#  'CTGTATGTCAGAGTGTAGAGG',
#  'TGTATGTCAGAGTGTAGAGGA',
#  'GTATGTCAGAGTGTAGAGGAA',
#  ...]
